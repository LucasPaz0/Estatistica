# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasPaz0/Estatistica/blob/main/ATV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def equacao(x):
    return (x**2 + 2*x + 1) * np.sin(x)

# %%
x_valores = np.linspace(-100, 100, 1000)

# %%
y_valores = equacao(x_valores)

# %%
df = pd.DataFrame({'x': x_valores, 'y': y_valores})

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['x'], df['y'], label='y = (x^2 + 2x + 1) * sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de y = (x^2 + 2x + 1) * sin(x)')
plt.grid(True)
plt.legend()
plt.show()
